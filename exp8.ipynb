# %%
# python program to accept 5 students name and roll number and map it into dictionary
students={}

name1=input("Enter student name:")
roll1=int(input("Enter roll number:"))
students[roll1]=name1

name2=input("Enter student name:")
roll2=int(input("Enter roll number:"))
students[roll2]=name2

name3=input("Enter student name:")
roll3=int(input("Enter roll number:"))
students[roll3]=name3

name4=input("Enter student name:")
roll4=int(input("Enter roll number:"))
students[roll4]=name4

name5=input("Enter student name:")
roll5=int(input("Enter roll number:"))
students[roll5]=name5

ascending=dict(sorted(students.items()))
descending=dict(sorted(students.items(),reverse=True))
print("Original dictionary:",students)
print("Ascending Order:",ascending)
print("Descending Order:",descending)
# Out:
# Enter student name:thajleena
# Enter roll number:39
# Enter student name:sreesha
# Enter roll number:37
# Enter student name:shekha
# Enter roll number:11
# Enter student name:rasha
# Enter roll number:28
# Enter student name:ameena
# Enter roll number:3
# Original dictionary: {39: 'thajleena', 37: 'sreesha', 11: 'shekha', 28: 'rasha', 3: 'ameena'}
# Ascending Order: {3: 'ameena', 11: 'shekha', 28: 'rasha', 37: 'sreesha', 39: 'thajleena'}
# Descending Order: {39: 'thajleena', 37: 'sreesha', 28: 'rasha', 11: 'shekha', 3: 'ameena'}

# %%
#Python program to accept 2 dictionaries (dic1 contains 3 students name and roll no.s,and dic2 contains 2 students names and roll no.s)Merge 2 dictionaries and display it[use update()]
dic1={} 
dic2={}
print("Enter 3 students for Dictionary 1:")
for i in range(3):
    name=input("Enter student name:")
    roll=int(input("Enter roll number:"))
    dic1[name]=roll
print("Enter 2 students for Dictionary 2:")
for i in range(2):
    name=input("Enter student name:")
    roll=int(input("Enter roll number:"))
    dic2[name]=roll
dic1.update(dic2)
print("\nMerged Dictionary:",dic1)
# Out:
# Enter 3 students for Dictionary 1:
# Enter student name:anu
# Enter roll number:1
# Enter student name:riya
# Enter roll number:2
# Enter student name:fathima
# Enter roll number:3
# Enter 2 students for Dictionary 2:
# Enter student name:meera
# Enter roll number:4
# Enter student name:sara
# Enter roll number:5
#
# Merged Dictionary: {'anu': 1, 'riya': 2, 'fathima': 3, 'meera': 4, 'sara': 5}
