# %%
#create a list of colors from coma seperated color names entered by user .display first and last colors 
colors=input("Enter colors:").split(",")
print("First color:",colors[0])
print("Last color:",colors[-1])
# Out:
# Enter colors: red,yelloe,blue
# First color: red
# Last color: blue

# %%
#A python program to accept a filename from the user, print extension of that file
filename=input("Enter filename:")
extension=filename.split(".")[-1]
print("Extension:",extension)
# Out:
# Enter filename: file.py
# Extension: py
