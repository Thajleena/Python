# %%
#Computing input value n to (n+nn+nnn)
n=input("Enter a number:")
nn=n+n
nnn=n+n+n
exp=int(n)+int(e1)+int(e2)
print(n,"+",nn,"+",nnn,"=",exp)
# Out:
# Enter a number: 5
# 5 + 55 + 555 = 615

# %%
# Area of the circle by inputting radius
from math import pi
r=int(input("Enter the radius of a circle:"))
area=pi*r*r
print("Area of circle:",area)
# Out:
# Enter the radius of a circle: 1
# Area of circle: 3.141592653589793

# %%
#Biggest of three input numbers using max()
n1=int(input("Enter first no:"))
n2=int(input("Enter second no:"))
n3=int(input("Enter third no:"))
Max=max(n1,n2,n3)
print("Maximum no:",Max)
# Out:
# Enter first no: 3
# Enter second no: 9
# Enter third no: 1
# Maximum no: 9
